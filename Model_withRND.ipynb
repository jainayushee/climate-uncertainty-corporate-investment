# %%
import pandas as pd

df = pd.read_csv("final_imputed_dataset1.csv")
df.isnull().sum()
# Calculate y = capx/at
df['y'] = df['capx'] / df['at']

# Calculate liquidity = act/lct
df['liquidity'] = df['act'] / df['lct']

# Calculate leverage = lct/ceq
df['leverage'] = df['lct'] / df['ceq']

# Assign size = at
df['size'] = df['at']

# Calculate roa = ni/at
df['roa'] = df['ni'] / df['at']

df['prev_inv'] = df['y'].shift(-1)

df['prev_year_at'] = df['at'].shift(1)

# Calculate the growth rate
df['asset_growth'] = df['at'] / df['prev_year_at']

# Drop the 'prev_year_at' column if not needed anymore
df.drop(columns=['prev_year_at'], inplace=True)

df.isnull().sum()
df = df[(df['fyear'] >= 2000) & (df['fyear'] <= 2021)]
df.isnull().sum()
# Out:
# Unnamed: 0         0
# GVKEY              0
# datadate           0
# fyear              0
# indfmt             0
# consol             0
# popsrc             0
# datafmt            0
# conm               0
# curcd              0
# aco                0
# act                0
# aqc                0
# at                 0
# capx               0
# ceq                0
# ebit               0
# icapt              0
# lct                0
# ni                 0
# revt               0
# seq                0
# xrd             2128
# xrdp            2141
# costat             0
# sic                0
# y                  0
# liquidity          0
# leverage           0
# size               0
# roa                0
# prev_inv           0
# asset_growth       0
# dtype: int64

# %%
df['xrd'].fillna(0, inplace=True)
df.isnull().sum()
# Out:
# Unnamed: 0         0
# GVKEY              0
# datadate           0
# fyear              0
# indfmt             0
# consol             0
# popsrc             0
# datafmt            0
# conm               0
# curcd              0
# aco                0
# act                0
# aqc                0
# at                 0
# capx               0
# ceq                0
# ebit               0
# icapt              0
# lct                0
# ni                 0
# revt               0
# seq                0
# xrd                0
# xrdp            2141
# costat             0
# sic                0
# y                  0
# liquidity          0
# leverage           0
# size               0
# roa                0
# prev_inv           0
# asset_growth       0
# dtype: int64

# %%
# adding cpu 
# Assuming df_cpu1 is your DataFrame containing the dataset
df_cpu1 = pd.read_csv('CPU index.csv')
# Convert 'date' column to datetime format with custom date parser
df_cpu1['date'] = pd.to_datetime(df_cpu1['date'], format='%b-%y')

# Extract year from 'date' column
df_cpu1['year'] = df_cpu1['date'].dt.year

# Drop the 'old_cpu_index' column
df_cpu1.drop(columns='old_cpu_index', inplace=True)

# Group by year and compute average cpu_index
average_cpu_index = df_cpu1.groupby('year')['cpu_index'].mean().reset_index()

# Verify the result
print(average_cpu_index)
combined_data = pd.merge(df, average_cpu_index, left_on='fyear', right_on='year', how='inner')
combined_data.shape
# Out:
#     year   cpu_index
# 0   1987   59.666897
# 1   1988   65.722413
# 2   1989   76.697151
# 3   1990   94.779705
# 4   1991   80.746618
# 5   1992   88.297105
# 6   1993   78.883753
# 7   1994   70.176454
# 8   1995   83.972636
# 9   1996   66.936481
# 10  1997   60.388895
# 11  1998   57.564906
# 12  1999   58.748100
# 13  2000   62.448747
# 14  2001   93.647460
# 15  2002   88.280674
# 16  2003   67.846581
# 17  2004   65.208485
# 18  2005   66.038375
# 19  2006   67.521463
# 20  2007  107.765643
# 21  2008   97.135520
# 22  2009   99.128977
# 23  2010  112.572259
# 24  2011  114.578606
# 25  2012  100.094996
# 26  2013   77.565805
# 27  2014   83.167437
# 28  2015   92.614515
# 29  2016  120.715749
# 30  2017  169.765549
# 31  2018  143.290591
# 32  2019  192.001778
# 33  2020  218.634176
# 34  2021  215.384017
# 35  2022  225.413245
# 36  2023  221.172666
# (6072, 35)

# %%
combined_data["GVKEY"].value_counts()
# Out:
# GVKEY
# 1075      22
# 12540     22
# 14225     22
# 13824     22
# 13714     22
#           ..
# 6730      22
# 6733      22
# 6774      22
# 6829      22
# 126721    22
# Name: count, Length: 276, dtype: int64

# %%
X = combined_data[['sic', 'liquidity', 'leverage', 'roa', 'icapt', 'aqc', 'prev_inv', 'cpu_index', 'asset_growth', 'xrd']]
y = combined_data['y']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Compute the correlation matrix
correlation_matrix = X.corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", vmin=-1, vmax=1)
plt.title('Correlation Heatmap of Independent Variables')
plt.xlabel('Independent Variables')
plt.ylabel('Independent Variables')
plt.show()

# %%
import numpy as np
X = X.applymap(lambda x: np.log(x) if x > 0 else x)
y = np.log(combined_data['y'])

# %%
combined_data.head()
# Out:
#    Unnamed: 0  GVKEY    datadate  fyear indfmt consol popsrc datafmt  \
# 0          27   1075  31/12/2000   2000   INDL      C      D     STD
# 1          52   1078  31/12/2000   2000   INDL      C      D     STD
# 2          78   1161  31/12/2000   2000   INDL      C      D     STD
# 3         104   1209  30/09/2000   2000   INDL      C      D     STD
# 4         130   1300  31/12/2000   2000   INDL      C      D     STD
#
#                            conm curcd  ...   sic         y  liquidity  \
# 0    PINNACLE WEST CAPITAL CORP   USD  ...  4911  0.092124   0.666427
# 1           ABBOTT LABORATORIES   USD  ...  3845  0.090899   1.716387
# 2        ADVANCED MICRO DEVICES   USD  ...  3674  0.139652   2.171121
# 3  AIR PRODUCTS & CHEMICALS INC   USD  ...  2810  0.092824   1.312918
# 4   HONEYWELL INTERNATIONAL INC   USD  ...  9997  0.033883   1.477821
#
#    leverage       size       roa  prev_inv  asset_growth  year  cpu_index
# 0  0.499975   7149.151  0.042289  0.130371      1.081810  2000  62.448747
# 1  0.501410  15283.254  0.182290  0.059633      1.056127  2000  62.448747
# 2  0.385951   5767.735  0.170435  0.120212      1.317527  2000  62.448747
# 3  0.487293   8270.500  0.015017  0.087616      1.004250  2000  62.448747
# 4  0.743175  25175.000  0.065899  0.036159      1.070047  2000  62.448747
#
# [5 rows x 35 columns]

# %%
import statsmodels.api as sm

X = sm.add_constant(X)

model = sm.OLS(y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.818
# Model:                            OLS   Adj. R-squared:                  0.817
# Method:                 Least Squares   F-statistic:                     2716.
# Date:                Tue, 05 Mar 2024   Prob (F-statistic):               0.00
# Time:                        17:49:00   Log-Likelihood:                -2158.1
# No. Observations:                6072   AIC:                             4338.
# Df Residuals:                    6061   BIC:                             4412.
# Df Model:                          10
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.3188      0.102      3.131      0.002       0.119       0.518
# sic             -0.0346      0.010     -3.395      0.001      -0.055      -0.015
# liquidity       -0.0341      0.008     -4.011      0.000      -0.051      -0.017
# leverage      4.571e-05      0.000      0.281      0.779      -0.000       0.000
# roa              0.0186      0.004      4.197      0.000       0.010       0.027
# icapt           -0.0020      0.002     -1.016      0.310      -0.006       0.002
# aqc              0.0001   5.36e-05      2.217      0.027    1.38e-05       0.000
# prev_inv         0.8721      0.006    143.019      0.000       0.860       0.884
# cpu_index       -0.0655      0.012     -5.324      0.000      -0.090      -0.041
# asset_growth    -0.2818      0.022    -12.982      0.000      -0.324      -0.239
# xrd             -0.0078      0.002     -4.838      0.000      -0.011      -0.005
# ==============================================================================
# Omnibus:                      717.080   Durbin-Watson:                   1.811
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5401.423
# Skew:                           0.304   Prob(JB):                         0.00
# Kurtosis:                       7.580   Cond. No.                     1.95e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.95e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
import statsmodels.api as sm

# Assuming df is your DataFrame containing the data

# Define your variables
predictors = ['sic', 'liquidity', 'leverage', 'size', 'roa', 'prev_inv', 'asset_growth', 'cpu_index', 'xrd', 'icapt']
target = 'y'

# # Add constant to the DataFrame
# df['const'] = 1

# Define the model
model = sm.OLS(combined_data[target], combined_data[predictors])

# Fit the model
result = model.fit()

# Print the summary
print(result.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.889
# Model:                            OLS   Adj. R-squared (uncentered):              0.889
# Method:                 Least Squares   F-statistic:                              4875.
# Date:                Tue, 05 Mar 2024   Prob (F-statistic):                        0.00
# Time:                        17:50:16   Log-Likelihood:                          14822.
# No. Observations:                6072   AIC:                                 -2.962e+04
# Df Residuals:                    6062   BIC:                                 -2.956e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# sic           7.726e-07   1.22e-07      6.314      0.000    5.33e-07    1.01e-06
# liquidity        0.0003      0.000      1.969      0.049    1.44e-06       0.001
# leverage      3.183e-06   9.59e-06      0.332      0.740   -1.56e-05     2.2e-05
# size         -1.783e-08   3.54e-08     -0.504      0.614   -8.72e-08    5.15e-08
# roa             -0.0137      0.002     -6.018      0.000      -0.018      -0.009
# prev_inv         0.9175      0.006    144.538      0.000       0.905       0.930
# asset_growth    -0.0005      0.000     -1.642      0.101      -0.001       0.000
# cpu_index     1.717e-05   4.94e-06      3.475      0.001    7.48e-06    2.69e-05
# xrd          -2.173e-07   1.56e-07     -1.397      0.163   -5.22e-07    8.77e-08
# icapt         3.819e-08    5.6e-08      0.681      0.496   -7.17e-08    1.48e-07
# ==============================================================================
# Omnibus:                     4559.244   Durbin-Watson:                   1.839
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           486632.232
# Skew:                           2.845   Prob(JB):                         0.00
# Kurtosis:                      46.486   Cond. No.                     1.44e+06
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 1.44e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
